# %%
#W2A1
print("Hello World!")
# Out:
# Hello World!

# %%
#W2A2
a = input("vui lòng nhập tên của bạn ")
print("xin chao",a)
# Out:
# vui lòng nhập tên của bạn Bảo
# xin chao Bảo

# %%
#W2A3
a= int(input ('nhập số nguyên: '))
b= int(input ('nhập số nguyên: '))
print("tổng là:", a + b)
print("hiệu là:", a - b)
print("tích là:", a * b)
print("thương là:", a / b)     
print("thương nguyên là:", a // b)   
print("phần dư là:", a % b)

# %%
#W2A4
a= float(input(' điểm hệ số 1 thứ nhất :'))
b= float(input(' điểm hệ số 1 thứ hai :'))
c= float(input(' điểm hệ số 1 thứ ba :'))
d= float(input('điểm hệ số 2 thứ nhất :'))
e= float(input("điểm hệ số 2 thứ hai :"))
f= float(input("điểm hệ số 3 thứ nhất:"))
print ('điểm trung bình môn ', (((a+b+c)+(e+d)*2+(f *3))/10))

# %%
#W2A5
a= int(input ('nhập số nguyên: '))
b= int(input ('nhập số nguyên: '))
print('a^b =', a**b)

# %%
#W2A6
a = input("Nhập một ký tự chữ cái thường ('a'...'z'): ")
print("Mã Unicode của ký tự:", ord(a))
ainhoa  = a.upper()
print("Ký tự hoa tương ứng:", ainhoa)

# %%
#W2A7
A = (13 ** 2) * 3
B = 13**2*3 + 5

# %%
#W2A8
C = float(input('độ C='))
F = (9 * C) / 5 + 32
Fed = round(F,2)
print('độ F =', Fed)

# %%
#w2A9
a = float(input('Nhập số tiền gốc: '))

print('giá gốc của điện thoai:', a )
print('số tiền bỏ ra để nhận điện thoại là :', a+ a*(0.3+0.1))

# %%
#W2A10
a = input("vui lòng nhập tên của bạn: ")
b = input("vui lòng nhập tên của bạn: ")
c = input("vui lòng nhập tên của bạn: ")
print ("hilu ", c,b,a)
# Out:
# vui lòng nhập tên của bạn: manh
# vui lòng nhập tên của bạn: bao
# vui lòng nhập tên của bạn: vinh
# hilu  vinh  bao  manh

# %%
#W2A11
a = int(input(' giờ :'))
b = int(input(' phút :'))
if a < 0 or b < 0 or b >= 60:
     print("Giờ hoặc phút không hợp lệ!")
else:
     print ('thời gian là :', a,'h',b,'m')
     print('thời gian theo số giây là :', (a*3600)+(b*60))

# %%
#12
a = int(input("do dai canh khoi rubik  la :"))
b = a*a*6
print(f"số miếng dán cần dán là :{b}")

# %%
#W2A13
a = int(input( ))
b = int(input( ))
c = a * b
hangdonvi =0
while c>=10:
    c=c%10
    hangdonvi=c
    c<10
print("chữ số hàng đơn vị là :", hangdonvi)

# %%
#14
a= a +b  
b=a -b 
a = a -b
print (a)
print(b)

# %%
#15
a= int(input())
def timsosao(n):
    if n < 0 : print("không có số sao âm")
    ketqua = n*(n-1)*6 +1 
    return ketqua 
timsosao(a)

# %%
#W2A16
print ("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
print(">  <")
print(" .  ")
print(" >  ")
# Out:
# >  <
#  .
#  >

# %%
#W2A18
print("### # #  ### ###")
print(" #  #  #  #  #")
print(" #  #  #  #  # ")
print(" #  #  #  #  # ")
print(" #  # #   #  #")
# Out:
# ### # #  ### ###
#  #  #  #  #  #
#  #  #  #  #  #
#  #  #  #  #  #
#  #  # #   #  #

# %%
#W2A19
A= ('Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday')
for i in A:
    print(i)
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#w2A20
A= ( 'January','February','March','April','May','June','July','August','September','October','November','December')
for i in A:
    print(i)
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#W2A21
for i in range(10):
  print( 'hello world')
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
